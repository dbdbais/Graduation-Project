# %%
# Load required libraries
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import time
import seaborn as sns
import sys
sys.setrecursionlimit(1500)
# %matplotlib inline

# %%
df_model = pd.read_csv('최종데이터/collect_train_1.csv')
df_model
# Out:
#                                                    text label
# 0     Norton SystemWorks 2002Software Suite\nProfess...  spam
# 1      set & forget ! blast your ad over 200 million...  spam
# 2     \nduly noteddefinately would make the extra ef...   ham
# 3      re : sevil yamen\nanne ,\nthanks .\nvince\nfr...   ham
# 4      are you ready to get it ?\nhello !\nviagra is...  spam
# ...                                                 ...   ...
# 5783   home depot * vs lowe ??s * ? which home cente...  spam
# 5784  You've won tkts to the EURO2004 CUP FINAL or 9...  spam
# 5785  Natalie (20/F) is inviting you to be her frien...  spam
# 5786  Ok lor... Sony ericsson salesman... I ask shuh...   ham
# 5787   affordable - the way medications should be\ni...  spam
#
# [5788 rows x 2 columns]

# %%
df_unseen_test = pd.read_csv('최종데이터/collect_test_1.csv')
df_unseen_test
# Out:
#                                                   text label
# 0    business in history that requires no work.  NO...  spam
# 1                   I'm in a meeting, call me later at   ham
# 2     re : var for metals\nted , anjam ' s and myse...   ham
# 3    My love ! How come it took you so long to leav...   ham
# 4                   I AM AT THE GAS STATION. GO THERE.   ham
# ..                                                 ...   ...
# 300  At 17:10 22/08/2002 +0100, Nick Hilliard wrote...  spam
# 301  URL: http://www.newsisfree.com/click/-2,865571...  spam
# 302  Welcome to UK-mobile-date this msg is FREE giv...  spam
# 303   all graphics software available , cheap oem v...  spam
# 304   norton systemworks 2002 final clearance 1093\...  spam
#
# [305 rows x 2 columns]

# %% [markdown]
# We will add two more columns to our dataframe for tokenized text and token count.

# %%
NEWLINE = '\n'

def token_count(row):
    'returns token count'
    text=row['tokenized_text']
    length=len(text.split())
    return length

def tokenize(row):
    "tokenize the text using default space tokenizer"
    text=row['text']
    lines=(line for line in text.split(NEWLINE) )
    tokenized=""
    for sentence in lines:
        tokenized+= " ".join(tok for tok in sentence.split())
    return tokenized

# %%
df_model['tokenized_text']=df_model.apply(tokenize, axis=1)
df_model['token_count']=df_model.apply(token_count, axis=1)
df_model['lang']='en'
df_model.head()
# Out:
#                                                 text label  \
# 0  Norton SystemWorks 2002Software Suite\nProfess...  spam
# 1   set & forget ! blast your ad over 200 million...  spam
# 2  \nduly noteddefinately would make the extra ef...   ham
# 3   re : sevil yamen\nanne ,\nthanks .\nvince\nfr...   ham
# 4   are you ready to get it ?\nhello !\nviagra is...  spam
#
#                                       tokenized_text  token_count lang
# 0  Norton SystemWorks 2002Software SuiteProfessio...           51   en
# 1  set & forget ! blast your ad over 200 million ...          145   en
# 2  duly noteddefinately would make the extra effo...          995   en
# 3  re : sevil yamenanne ,thanks .vincefrom : anne...           76   en
# 4  are you ready to get it ?hello !viagra is the ...           68   en

# %%
df_unseen_test['tokenized_text']=df_unseen_test.apply(tokenize, axis=1)
df_unseen_test['token_count']=df_unseen_test.apply(token_count, axis=1)
df_unseen_test['lang']='en'
df_unseen_test.head()
# Out:
#                                                 text label  \
# 0  business in history that requires no work.  NO...  spam
# 1                 I'm in a meeting, call me later at   ham
# 2   re : var for metals\nted , anjam ' s and myse...   ham
# 3  My love ! How come it took you so long to leav...   ham
# 4                 I AM AT THE GAS STATION. GO THERE.   ham
#
#                                       tokenized_text  token_count lang
# 0  business in history that requires no work. NON...           15   en
# 1                 I'm in a meeting, call me later at            8   en
# 2  re : var for metalsted , anjam ' s and myself ...           53   en
# 3  My love ! How come it took you so long to leav...           35   en
# 4                 I AM AT THE GAS STATION. GO THERE.            8   en

# %%
# Lets look at some information related to the data
print("total emails : ", len(df_model))
print  ("total spam emails : ", len(df_model[df_model['label']=='spam']) )
print  ("total normal emails : ", len(df_model[df_model['label']=='ham']) )
# Out:
# total emails :  5788
# total spam emails :  2881
# total normal emails :  2907

# %%
bins = [0,100,200,300,350,400,500,600,800,1000,1500,2000,3000,4000,5000,6000,10000,20000]


fig, axes = plt.subplots(nrows=1, ncols=2,figsize=(12, 6))
fig.subplots_adjust(hspace=.5)

df_model_sub=df_model[ (df_model['lang']=='en') & (df_model['label']=='ham')]
df_model1 = df_model_sub.groupby(pd.cut(df_model_sub['token_count'], bins=bins)).token_count.count()
df_model1.index=[a.right for a in df_model1.index]
res1=df_model1.plot(kind='bar',ax=axes[0])
res1.set_xlabel('Email tokens length')
res1.set_ylabel('Frequency')
res1.set_title('Token length Vs Frequency for Enron Normal Emails')


df_model_sub=df_model[ (df_model['lang']=='en') & (df_model['label']=='spam')]
df_model1 = df_model_sub.groupby(pd.cut(df_model_sub['token_count'], bins=bins)).token_count.count()
df_model1.index=[a.right for a in df_model1.index]
res2=df_model1.plot(kind='bar',ax=axes[1])
res2.set_xlabel('Email tokens length')
res2.set_ylabel('Frequency')
res2.set_title('Token length Vs Frequency for Enron Spam Emails')
# Out:
# Text(0.5, 1.0, 'Token length Vs Frequency for Enron Spam Emails')

# %% [markdown]
# # Train Machine Learning Models

# %% [markdown]
# ## Deep Learning Model

# %% [markdown]
# We will build our deep learning model using Keras library with tensorflow as backend.

# %%
import keras

from keras.layers import Input, Dense
from keras.models import Model,load_model
from keras.layers import Input, Dense
from keras.models import Model
from keras import regularizers

from keras.preprocessing.text import Tokenizer
from keras.models import Sequential
from keras.layers import Dense, Dropout, Activation
from keras.callbacks import ModelCheckpoint, TensorBoard

# %%
import sklearn
from sklearn import metrics
from sklearn import svm
import joblib
from sklearn.preprocessing import LabelEncoder

# %% [markdown]
# # Create tf-idf model from the data
#
# We will create tf-idf model with keras

# %%
# max number of features
num_max = 4000

# %%
def train_tf_idf_model(texts):
    "train tf idf model "
    tic = time.process_time()
    

    tok = Tokenizer(num_words=num_max)
    tok.fit_on_texts(texts)
    toc = time.process_time()

    print (" -----total Computation time = " + str((toc - tic)) + " seconds")
    return tok


def prepare_model_input(tfidf_model,dataframe,mode='tfidf'):
    
    "function to prepare data input features using tfidf model"
    tic = time.process_time()
    
    le = LabelEncoder()
    sample_texts = list(dataframe['tokenized_text'])
    sample_texts = [' '.join(x.split()) for x in sample_texts]
    
    targets=list(dataframe['label'])
    targets = [1. if x=='spam' else 0. for x in targets]
    sample_target = le.fit_transform(targets)
    
    if mode=='tfidf':
        sample_texts=tfidf_model.texts_to_matrix(sample_texts,mode='tfidf')
    else:
        sample_texts=tfidf_model.texts_to_matrix(sample_texts)
    
    toc = time.process_time()
    
    print('shape of labels: ', sample_target.shape)
    print('shape of data: ', sample_texts.shape)
    
    print (" -----total Computation time for preparing model data = " + str((toc - tic)) + " seconds")
    
    return sample_texts,sample_target

# %%
texts=list(df_model['tokenized_text'])
tfidf_model=train_tf_idf_model(texts)
# Out:
#  -----total Computation time = 1.4375 seconds

# %%
# prepare model input data
mat_texts,tags=prepare_model_input(tfidf_model,df_model,mode='tfidf')
# Out:
# shape of labels:  (5788,)
# shape of data:  (5788, 4000)
#  -----total Computation time for preparing model data = 4.671875 seconds

# %% [markdown]
# # Split Train/validation data
#
# We will use 85% for training, 15% for validation.

# %%
from sklearn.model_selection import train_test_split

X_train, X_val, y_train, y_val = train_test_split(mat_texts, tags, test_size=0.15, random_state=42)
print ('train data shape: ', X_train.shape, y_train.shape)
print ('validation data shape :' , X_val.shape, y_val.shape)
# Out:
# train data shape:  (4919, 4000) (4919,)
# validation data shape : (869, 4000) (869,)

# %%
X_train
# Out:
# array([[0.        , 0.        , 0.        , ..., 0.        , 0.        ,
#         0.        ],
#        [0.        , 1.49392902, 0.83307517, ..., 0.        , 0.        ,
#         0.        ],
#        [0.        , 2.46327698, 0.83307517, ..., 0.        , 0.        ,
#         0.        ],
#        ...,
#        [0.        , 0.        , 2.17385793, ..., 0.        , 0.        ,
#         0.        ],
#        [0.        , 3.82247102, 3.08908455, ..., 0.        , 0.        ,
#         0.        ],
#        [0.        , 0.        , 0.        , ..., 0.        , 0.        ,
#         0.        ]])

# %% [markdown]
# # Build models

# %% [markdown]
# ## Define and initialize the network

# %%
model_save_path="checkpoints/spam_detector_enron_model.h5"

# %%
def get_simple_model():
    model = Sequential()
    model.add(Dense(512, activation='relu', input_shape=(num_max,)))
    model.add(Dropout(0.5))
    model.add(Dense(256, activation='relu'))
    model.add(Dropout(0.5))
    model.add(Dense(1, activation='sigmoid'))
    model.summary()
    model.compile(loss='binary_crossentropy',
              optimizer='adam',
              metrics=['acc',keras.metrics.binary_accuracy])
    print('compile done')
    return model

def check_model(model,x,y,epochs=2):
    history=model.fit(x,y,batch_size=32,epochs=epochs,verbose=1,shuffle=True,validation_split=0.2,
              callbacks=[checkpointer, tensorboard]).history
    return history


def check_model2(model,x_train,y_train,x_val,y_val,epochs=10):
    history=model.fit(x_train,y_train,batch_size=64,
                      epochs=epochs,verbose=1,
                      shuffle=True,
                      validation_data=(x_val, y_val),
                      callbacks=[checkpointer, tensorboard]).history
    return history

# define checkpointer
checkpointer = ModelCheckpoint(filepath=model_save_path,
                               verbose=1,
                               save_best_only=True)    

# define tensorboard
tensorboard = TensorBoard(log_dir='./logs',
                          histogram_freq=0,
                          write_graph=True,
                          write_images=True)


# define the predict function for the deep learning model for later use
def predict(data):
    result=model.predict(data)
    prediction = [round(x[0]) for x in result]
    return prediction

# %% [markdown]
# ## Train the model

# %%
# get the compiled model
model = get_simple_model()

# load history
# history=check_model(m,mat_texts,tags,epochs=10)
history=check_model2(model,X_train,y_train,X_val,y_val,epochs=20)
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 512)               2048512
#
#  dropout (Dropout)           (None, 512)               0
#
#  dense_1 (Dense)             (None, 256)               131328
#
#  dropout_1 (Dropout)         (None, 256)               0
#
#  dense_2 (Dense)             (None, 1)                 257
#
# =================================================================
# Total params: 2180097 (8.32 MB)
# Trainable params: 2180097 (8.32 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# compile done
# Epoch 1/20
# 77/77 [==============================] - ETA: 0s - loss: 0.3615 - acc: 0.8504 - binary_accuracy: 0.8504
# Epoch 1: val_loss improved from inf to 0.19196, saving model to checkpoints\spam_detector_enron_model.h5
# 77/77 [==============================] - 5s 40ms/step - loss: 0.3615 - acc: 0.8504 - binary_accuracy: 0.8504 - val_loss: 0.1920 - val_acc: 0.9390 - val_binary_accuracy: 0.9390
# Epoch 2/20
#  3/77 [>.............................] - ETA: 2s - loss: 0.1466 - acc: 0.9688 - binary_accuracy: 0.9688
# C:\Users\JAE\anaconda3\lib\site-packages\keras\src\engine\training.py:3000: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 77/77 [==============================] - ETA: 0s - loss: 0.1386 - acc: 0.9602 - binary_accuracy: 0.9602
# Epoch 2: val_loss improved from 0.19196 to 0.17851, saving model to checkpoints\spam_detector_enron_model.h5
# 77/77 [==============================] - 3s 35ms/step - loss: 0.1386 - acc: 0.9602 - binary_accuracy: 0.9602 - val_loss: 0.1785 - val_acc: 0.9551 - val_binary_accuracy: 0.9551
# Epoch 3/20
# 77/77 [==============================] - ETA: 0s - loss: 0.0854 - acc: 0.9742 - binary_accuracy: 0.9742
# Epoch 3: val_loss did not improve from 0.17851
# 77/77 [==============================] - 3s 34ms/step - loss: 0.0854 - acc: 0.9742 - binary_accuracy: 0.9742 - val_loss: 0.1809 - val_acc: 0.9551 - val_binary_accuracy: 0.9551
# Epoch 4/20
# 77/77 [==============================] - ETA: 0s - loss: 0.0456 - acc: 0.9872 - binary_accuracy: 0.9872
# Epoch 4: val_loss did not improve from 0.17851
# 77/77 [==============================] - 3s 34ms/step - loss: 0.0456 - acc: 0.9872 - binary_accuracy: 0.9872 - val_loss: 0.2374 - val_acc: 0.9459 - val_binary_accuracy: 0.9459
# Epoch 5/20
# 77/77 [==============================] - ETA: 0s - loss: 0.0325 - acc: 0.9917 - binary_accuracy: 0.9917
# Epoch 5: val_loss did not improve from 0.17851
# 77/77 [==============================] - 3s 34ms/step - loss: 0.0325 - acc: 0.9917 - binary_accuracy: 0.9917 - val_loss: 0.2667 - val_acc: 0.9436 - val_binary_accuracy: 0.9436
# Epoch 6/20
# 77/77 [==============================] - ETA: 0s - loss: 0.0204 - acc: 0.9945 - binary_accuracy: 0.9945
# Epoch 6: val_loss did not improve from 0.17851
# 77/77 [==============================] - 3s 35ms/step - loss: 0.0204 - acc: 0.9945 - binary_accuracy: 0.9945 - val_loss: 0.2856 - val_acc: 0.9505 - val_binary_accuracy: 0.9505
# Epoch 7/20
# 76/77 [============================>.] - ETA: 0s - loss: 0.0173 - acc: 0.9959 - binary_accuracy: 0.9959
# Epoch 7: val_loss did not improve from 0.17851
# 77/77 [==============================] - 3s 35ms/step - loss: 0.0172 - acc: 0.9959 - binary_accuracy: 0.9959 - val_loss: 0.3139 - val_acc: 0.9517 - val_binary_accuracy: 0.9517
# Epoch 8/20
# 77/77 [==============================] - ETA: 0s - loss: 0.0166 - acc: 0.9955 - binary_accuracy: 0.9955
# Epoch 8: val_loss did not improve from 0.17851
# 77/77 [==============================] - 3s 34ms/step - loss: 0.0166 - acc: 0.9955 - binary_accuracy: 0.9955 - val_loss: 0.4077 - val_acc: 0.9494 - val_binary_accuracy: 0.9494
# Epoch 9/20
# 76/77 [============================>.] - ETA: 0s - loss: 0.0155 - acc: 0.9965 - binary_accuracy: 0.9965
# Epoch 9: val_loss did not improve from 0.17851
# 77/77 [==============================] - 3s 34ms/step - loss: 0.0153 - acc: 0.9965 - binary_accuracy: 0.9965 - val_loss: 0.3320 - val_acc: 0.9471 - val_binary_accuracy: 0.9471
# Epoch 10/20
# 76/77 [============================>.] - ETA: 0s - loss: 0.0381 - acc: 0.9940 - binary_accuracy: 0.9940
# Epoch 10: val_loss did not improve from 0.17851
# 77/77 [==============================] - 3s 36ms/step - loss: 0.0378 - acc: 0.9941 - binary_accuracy: 0.9941 - val_loss: 0.3432 - val_acc: 0.9448 - val_binary_accuracy: 0.9448
# Epoch 11/20
# 77/77 [==============================] - ETA: 0s - loss: 0.0711 - acc: 0.9872 - binary_accuracy: 0.9872
# Epoch 11: val_loss did not improve from 0.17851
# 77/77 [==============================] - 3s 34ms/step - loss: 0.0711 - acc: 0.9872 - binary_accuracy: 0.9872 - val_loss: 0.3618 - val_acc: 0.9229 - val_binary_accuracy: 0.9229
# Epoch 12/20
# 76/77 [============================>.] - ETA: 0s - loss: 0.0406 - acc: 0.9930 - binary_accuracy: 0.9930
# Epoch 12: val_loss did not improve from 0.17851
# 77/77 [==============================] - 3s 35ms/step - loss: 0.0403 - acc: 0.9929 - binary_accuracy: 0.9929 - val_loss: 0.2707 - val_acc: 0.9379 - val_binary_accuracy: 0.9379
# Epoch 13/20
# 76/77 [============================>.] - ETA: 0s - loss: 0.0126 - acc: 0.9965 - binary_accuracy: 0.9965
# Epoch 13: val_loss did not improve from 0.17851
# 77/77 [==============================] - 3s 34ms/step - loss: 0.0128 - acc: 0.9963 - binary_accuracy: 0.9963 - val_loss: 0.4182 - val_acc: 0.9471 - val_binary_accuracy: 0.9471
# Epoch 14/20
# 77/77 [==============================] - ETA: 0s - loss: 0.0117 - acc: 0.9980 - binary_accuracy: 0.9980
# Epoch 14: val_loss did not improve from 0.17851
# 77/77 [==============================] - 3s 35ms/step - loss: 0.0117 - acc: 0.9980 - binary_accuracy: 0.9980 - val_loss: 0.4052 - val_acc: 0.9436 - val_binary_accuracy: 0.9436
# Epoch 15/20
# 77/77 [==============================] - ETA: 0s - loss: 0.0208 - acc: 0.9961 - binary_accuracy: 0.9961
# Epoch 15: val_loss did not improve from 0.17851
# 77/77 [==============================] - 3s 35ms/step - loss: 0.0208 - acc: 0.9961 - binary_accuracy: 0.9961 - val_loss: 0.4115 - val_acc: 0.9517 - val_binary_accuracy: 0.9517
# Epoch 16/20
# 76/77 [============================>.] - ETA: 0s - loss: 0.0066 - acc: 0.9979 - binary_accuracy: 0.9979
# Epoch 16: val_loss did not improve from 0.17851
# 77/77 [==============================] - 3s 34ms/step - loss: 0.0066 - acc: 0.9980 - binary_accuracy: 0.9980 - val_loss: 0.4214 - val_acc: 0.9425 - val_binary_accuracy: 0.9425
# Epoch 17/20
# 77/77 [==============================] - ETA: 0s - loss: 0.0066 - acc: 0.9986 - binary_accuracy: 0.9986
# Epoch 17: val_loss did not improve from 0.17851
# 77/77 [==============================] - 3s 34ms/step - loss: 0.0066 - acc: 0.9986 - binary_accuracy: 0.9986 - val_loss: 0.6104 - val_acc: 0.9471 - val_binary_accuracy: 0.9471
# Epoch 18/20
# 77/77 [==============================] - ETA: 0s - loss: 0.0223 - acc: 0.9963 - binary_accuracy: 0.9963
# Epoch 18: val_loss did not improve from 0.17851
# 77/77 [==============================] - 3s 34ms/step - loss: 0.0223 - acc: 0.9963 - binary_accuracy: 0.9963 - val_loss: 0.5450 - val_acc: 0.9471 - val_binary_accuracy: 0.9471
# Epoch 19/20
# 77/77 [==============================] - ETA: 0s - loss: 0.0147 - acc: 0.9970 - binary_accuracy: 0.9970
# Epoch 19: val_loss did not improve from 0.17851
# 77/77 [==============================] - 3s 33ms/step - loss: 0.0147 - acc: 0.9970 - binary_accuracy: 0.9970 - val_loss: 0.5415 - val_acc: 0.9413 - val_binary_accuracy: 0.9413
# Epoch 20/20
# 76/77 [============================>.] - ETA: 0s - loss: 0.0129 - acc: 0.9975 - binary_accuracy: 0.9975
# Epoch 20: val_loss did not improve from 0.17851
# 77/77 [==============================] - 3s 33ms/step - loss: 0.0128 - acc: 0.9976 - binary_accuracy: 0.9976 - val_loss: 0.5082 - val_acc: 0.9459 - val_binary_accuracy: 0.9459

# %% [markdown]
# The results on validation data looks very good. Lets plot the loss on train and validation data

# %%
plt.plot(history['loss'])
plt.plot(history['val_loss'])
plt.title('Email Spam Filter Model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper right');

# %% [markdown]
# # Evaluate Model Performance

# %% [markdown]
# ## Lets prepare test data

# %%
sample_texts,sample_target=prepare_model_input(tfidf_model,df_unseen_test,mode='')
# Out:
# shape of labels:  (305,)
# shape of data:  (305, 4000)
#  -----total Computation time for preparing model data = 0.078125 seconds

# %%
# lets write a function to create the dataframe of the results from all the models
model_dict={}
model_dict['deep_learning']=model


def getResults(model_dict,sample_texts,sample_target):
    '''
    Get results from different models
    '''
    results=[]
    
    results_cm={}
    
    for name,model in model_dict.items():
#         print(name)
        tic1 = time.process_time()
        if name in 'deep_learning':
            predicted_sample = predict(sample_texts)
        else:    
            predicted_sample = model.predict(sample_texts)
        toc1 = time.process_time()
#         print(predicted_sample)

        cm=sklearn.metrics.confusion_matrix(sample_target, predicted_sample)
        results_cm[name]=cm
        
        total=len(predicted_sample)
        TP = cm[0][0]
        FP = cm[0][1]
        FN = cm[1][0]
        TN = cm[1][1]
        
        time_taken=round(toc1 - tic1,4)
        res=sklearn.metrics.precision_recall_fscore_support(sample_target, predicted_sample)
        results.append([name,np.mean(res[0]),np.mean(res[1]),np.mean(res[2]),total,TP,FP,FN,TN,str(time_taken)] )
        
        
    
    df_cols=['model','precision','recall','f1_score','Total_samples','TP','FP','FN','TN','execution_time']
    result_df=pd.DataFrame(results,columns=df_cols)
    
    return result_df,results_cm

# %% [markdown]
# ## Results

# %%
result_df,results_cm= getResults(model_dict,sample_texts,sample_target)
result_df
# Out:
# 10/10 [==============================] - 0s 5ms/step
#            model  precision    recall  f1_score  Total_samples   TP  FP  FN  \
# 0  deep_learning   0.908333  0.905699  0.904816            305  143   7  22
#
#     TN execution_time
# 0  133         0.5156

# %% [markdown]
# As we see, deep learning model does very well on the test data. The results from other models are close. I have tried this approach over multiple language emails and deep learning model is very consistent with the performance. XGboost also does very well. Please note that i have not optimized random forest and SVM much beyond the defaults. So they may have better performance with tuning.

# %% [markdown]
# ### Plot confusion Matrix for all the models

# %%
def plot_heatmap(cm,title):
    df_cm2 = pd.DataFrame(cm, index = ['normal', 'spam'])
    df_cm2.columns=['normal','spam']

    ax = plt.axes()
    sns.heatmap(df_cm2, annot=True, fmt="d", linewidths=.5,ax=ax)
    ax.set_title(title)
    plt.show()
    return

# %% [markdown]
# ### CM for Deep Learning Model

# %%
plot_heatmap(results_cm['deep_learning'],'Deep Learning')

# %% [markdown]
# ## 다른 테스트 셋

# %% [markdown]
# ### create(GPT)

# %%
create = pd.read_csv('최종데이터/create_test_1.csv')
create
# Out:
#                                                   text label
# 0    Subject: Limited Spots Left - Grab Yours Now! ...  spam
# 1    Hi jane,\n\nKeep creating and exploring your p...   ham
# 2    Subject: No More Debt Worries: Recover Instant...  spam
# 3    Subject: A Truly Joyful Trip\nHi Jinger@@@\nI ...   ham
# 4    Grateful for our friendship. You mean a lot to...   ham
# ..                                                 ...   ...
# 195  Subject: Your Guaranteed Satisfaction\n\nHi ma...  spam
# 196  Looking for a bargain? Compare rates and save ...  spam
# 197  Hello clinst,\n\nElevate your education with o...  spam
# 198  Subject: Request for Exchange due to iPad Soun...   ham
# 199  Hi John,\n\nI had an amazing time at jane's ho...   ham
#
# [200 rows x 2 columns]

# %%
create['tokenized_text']=create.apply(tokenize, axis=1)
create['token_count']=create.apply(token_count, axis=1)
create['lang']='en'

sample_texts,sample_target=prepare_model_input(tfidf_model,create,mode='')
result_df,results_cm= getResults(model_dict,sample_texts,sample_target)
result_df
# Out:
# shape of labels:  (200,)
# shape of data:  (200, 4000)
#  -----total Computation time for preparing model data = 0.015625 seconds
# 7/7 [==============================] - 0s 8ms/step
#            model  precision    recall  f1_score  Total_samples  TP  FP  FN  \
# 0  deep_learning   0.854442  0.856045  0.854706            200  81  12  17
#
#    TN execution_time
# 0  90           0.25

# %% [markdown]
# ### image

# %%
image = pd.read_csv('최종데이터/image_test_1.csv')
image
# Out:
#                                                  text label
# 0   \nADS FOR MONSTERS\nMADHOUSE SALUTES THE TRANS...   ham
# 1   \nBest stock Pick for this Year.\nGet ARSS Fir...  spam
# 2   \n• Lowest Price Guarantee Fast Delivery\nFor ...  spam
# 3              \nLOUIS VUITTON\nPARIS\nmade in France   ham
# 4   \n• Lowest Price Guarantee Fast Delivery\nFor ...  spam
# ..                                                ...   ...
# 57  \nNERDS ANONYMOUS\nCreated by Jared Bonner and...   ham
# 58  \nCANAL DE PANAMA\nABIER\nMIRAFLORES LOCKS PAN...   ham
# 59  \nLowest Price Guarantee & Fast Delivery\n100%...  spam
# 60  \nWATCH OUT!\nSBNS MAKES A MOVE!\nWATCH SBNS T...  spam
# 61  \nGet QEGY First Thing On Monday Oct 23, This ...  spam
#
# [62 rows x 2 columns]

# %%
image['tokenized_text']=image.apply(tokenize, axis=1)
image['token_count']=image.apply(token_count, axis=1)
image['lang']='en'

sample_texts,sample_target=prepare_model_input(tfidf_model,image,mode='')
result_df,results_cm= getResults(model_dict,sample_texts,sample_target)
result_df
# Out:
# shape of labels:  (62,)
# shape of data:  (62, 4000)
#  -----total Computation time for preparing model data = 0.0 seconds
# 2/2 [==============================] - 0s 0s/step
#            model  precision    recall  f1_score  Total_samples  TP  FP  FN  \
# 0  deep_learning   0.676071  0.676071  0.676071             62  23  10  10
#
#    TN execution_time
# 0  19         0.1406

# %% [markdown]
# ### collect+image

# %%
collectimage = pd.read_csv('최종데이터/collectimage_test_16features.csv')
collectimage
# Out:
#                                                   text  special_ratio  \
# 0    \nFeel young again with Regenisis HGH\nRegenis...       0.118319
# 1    \nSuperstar Stock Report\nSmart Money Equities...       0.129388
# 2    \nYOU'VE SEEN IT BEFORE YOU SAY? YOU AIN'T SEE...       0.194393
# 3    \n****! READ IT CAREFULLY!**\nNew Product Incr...       0.103499
# 4    \nDOE MEE\nDOE MEE DOE MEE DOE MEE DOE MEE DOE...       0.123539
# ..                                                 ...            ...
# 300  \nGet QEGY First Thing On Monday Oct 23, This ...       0.147568
# 301  \n??Lowest Price Guarantee Fast Delivery\nFor ...       0.178926
# 302  \nLOUIS VUITTON\nPARIS\nmade in FranceUrgent -...       0.111481
# 303  \nFeel young again with Regenisis HGH\nRegenis...       0.288982
# 304  \nHoodia Maximum Strength\nFinally... A Natura...       0.123773
#
#      number_ratio  url_count  upper_ratio  blank_ratio  crlf_ratio      Noun  \
# 0        0.028868          0     0.067479     0.290053    0.120768  0.362963
# 1        0.107814          2     0.159635     0.343152    0.030367  0.337097
# 2        0.308285          0     0.276236     0.308322    0.528875  0.415842
# 3        0.041612          0     0.072706     0.334076    0.065231  0.341686
# 4        0.087075          0     0.474921     0.408219    0.076128  0.581818
# ..            ...        ...          ...          ...         ...       ...
# 300      0.246343          0     0.209392     0.360201    0.055422  0.368421
# 301      0.270859          2     0.052989     0.371872    0.142004  0.271186
# 302      0.530387          0     0.308901     0.275880    0.124529  0.500000
# 303      0.096482          2     0.060748     0.273385    0.124622  0.307500
# 304      0.057451          0     0.081388     0.314493    0.300497  0.390909
#
#       Pronoun      Verb  Adjective    Adverb  avg_word_sentences  \
# 0    0.037037  0.140741   0.088889  0.044444            0.134549
# 1    0.074194  0.140323   0.051613  0.043548            0.126329
# 2    0.016502  0.075908   0.046205  0.019802            0.066148
# 3    0.056948  0.125285   0.075171  0.041002            0.103684
# 4    0.018182  0.036364   0.000000  0.018182            0.171220
# ..        ...       ...        ...       ...                 ...
# 300  0.010526  0.089474   0.036842  0.015789            0.096210
# 301  0.090395  0.124294   0.050847  0.045198            0.062253
# 302  0.031250  0.031250   0.062500  0.000000            0.086876
# 303  0.030000  0.122500   0.075000  0.045000            0.214004
# 304  0.059091  0.122727   0.063636  0.036364            0.103989
#
#      avg_char_sentences  avg_word_paragraphs  avg_char_paragraphs label
# 0              0.136043             0.040308             0.044780  spam
# 1              0.112799             0.182118             0.194045  spam
# 2              0.054741             0.099670             0.082251  spam
# 3              0.101180             0.141810             0.145145  spam
# 4              0.135614             0.015024             0.011739  spam
# ..                  ...                  ...                  ...   ...
# 300            0.078858             0.054232             0.051699  spam
# 301            0.053874             0.055332             0.048433  spam
# 302            0.094422             0.007329             0.008396  spam
# 303            0.190966             0.106632             0.127420  spam
# 304            0.097211             0.072188             0.067092  spam
#
# [305 rows x 17 columns]

# %%
collectimage['tokenized_text']=collectimage.apply(tokenize, axis=1)
collectimage['token_count']=collectimage.apply(token_count, axis=1)
collectimage['lang']='en'

sample_texts,sample_target=prepare_model_input(tfidf_model,collectimage,mode='')
result_df,results_cm= getResults(model_dict,sample_texts,sample_target)
result_df
# Out:
# shape of labels:  (305,)
# shape of data:  (305, 4000)
#  -----total Computation time for preparing model data = 0.140625 seconds
# 10/10 [==============================] - 0s 5ms/step
#            model  precision   recall  f1_score  Total_samples  TP  FP  FN  \
# 0  deep_learning   0.729889  0.78663  0.725871            305  74  10  68
#
#     TN execution_time
# 0  153         0.3438

# %% [markdown]
# ### create+image

# %%
createimage = pd.read_csv('최종데이터/createimage_test_16features.csv')
createimage
# Out:
#                                                   text  special_ratio  \
# 0    \nPARK HYATT TOKYOSubject: Congratulations! Yo...       0.530790
# 1    \nFNLH EXPLODES ON THE INVESTOR SCENE!!!\nTHIS...       0.377405
# 2    \nDANGER\nThis beach Lumahai is NOT A WARNING ...       0.256490
# 3    \nThis may turn out to be the most important e...       0.318424
# 4    \nGDKI.PK IS POISED TO EXPLODE!\nTHIS ONE COUL...       0.462681
# ..                                                 ...            ...
# 181  \nBIG NEWS\nARE HITTING ON FRIDAY FOR CRSVF!!!...       0.422137
# 182  \nHoodia Maximum Strength\nFinally... A Natura...       0.289102
# 183  \nLowest Price Guarantee & Fast Delivery\n100%...       0.711749
# 184  \nMastering MuseScore\nMarc Sabate\nMastering ...       0.000000
# 185  \n??Q\nINTENTIONAL EXCELLENCE IN ORGANIZATIONS...       0.359816
#
#      number_ratio  url_count  upper_ratio  blank_ratio  crlf_ratio      Noun  \
# 0        0.203366          1     0.129727     0.475949    0.356645  0.387755
# 1        0.133960          0     0.223838     0.837510    0.193030  0.340996
# 2        0.000000          0     0.185293     0.638729    0.505035  0.361446
# 3        0.123090          0     0.107310     0.742559    0.161889  0.368932
# 4        0.208157          0     0.467605     0.701375    0.291156  0.512821
# ..            ...        ...          ...          ...         ...       ...
# 181      0.110708          1     0.377725     0.613151    0.231352  0.479029
# 182      0.096566          0     0.112412     0.631050    0.363225  0.401361
# 183      1.000000          3     0.119216     0.637573    0.440688  0.403361
# 184      0.137235          0     0.172633     0.076582    0.922754  0.704918
# 185      0.270853          0     0.121153     0.647877    0.096355  0.377358
#
#       Pronoun      Verb  Adjective    Adverb  avg_word_sentences  \
# 0    0.081633  0.102041   0.081633  0.040816            0.059309
# 1    0.068966  0.122605   0.053640  0.022989            0.171922
# 2    0.060241  0.096386   0.060241  0.060241            0.066631
# 3    0.043689  0.123786   0.053398  0.026699            0.196847
# 4    0.019231  0.070513   0.035256  0.016026            0.182838
# ..        ...       ...        ...       ...                 ...
# 181  0.017660  0.075055   0.048565  0.015453            0.209218
# 182  0.081633  0.122449   0.054422  0.034014            0.168511
# 183  0.042017  0.109244   0.016807  0.033613            0.439660
# 184  0.049180  0.049180   0.049180  0.000000            0.193451
# 185  0.031447  0.157233   0.056604  0.031447            0.159491
#
#      avg_char_sentences  avg_word_paragraphs  avg_char_paragraphs label
# 0              0.074385             0.010664             0.009254  spam
# 1              0.165509             0.092417             0.074148  spam
# 2              0.068221             0.021801             0.014104   ham
# 3              0.210125             0.194905             0.178347  spam
# 4              0.181061             0.109005             0.094865  spam
# ..                  ...                  ...                  ...   ...
# 181            0.226992             0.277251             0.275786  spam
# 182            0.186529             0.139810             0.125238  spam
# 183            0.441485             0.225118             0.194148  spam
# 184            0.290367             0.125592             0.137527  spam
# 185            0.193157             0.308057             0.318361  spam
#
# [186 rows x 17 columns]

# %%
createimage['tokenized_text']=createimage.apply(tokenize, axis=1)
createimage['token_count']=createimage.apply(token_count, axis=1)
createimage['lang']='en'

sample_texts,sample_target=prepare_model_input(tfidf_model,createimage,mode='')
result_df,results_cm= getResults(model_dict,sample_texts,sample_target)
result_df
# Out:
# shape of labels:  (186,)
# shape of data:  (186, 4000)
#  -----total Computation time for preparing model data = 0.03125 seconds
# 6/6 [==============================] - 0s 4ms/step
#            model  precision    recall  f1_score  Total_samples  TP  FP  FN  \
# 0  deep_learning   0.762097  0.827696  0.781059            186  36   7  26
#
#     TN execution_time
# 0  117         0.2812
